# %%
import pandas as pd
import os
import numpy as np
import xgboost as xgb

# %%
os.chdir("C:\\Users\\chanqun\\Downloads\\ops")

# %%
df = pd.read_csv('Regular_Season_Batter.csv')
df_16 = df[df['year'] == 2016]
df_17 = df[df['year'] == 2017]
# Out:
#       batter_id batter_name  year team    avg    G   AB    R    H  2B  \
# 5             1         강경학  2017   한화  0.214   59   84   17   18   2
# 10            2         강구성  2017   NC  0.000    1    1    0    0   0
# 55            4         강민호  2017   롯데  0.285  130  456   62  130  22
# 84            8         강상원  2017   한화  0.214   33   14    8    3   1
# 87            9         강승호  2017   LG  0.250   85  248   42   62  14
# 99           11         강진성  2017   NC  0.296   28   27    5    8   3
# 104          12         강한울  2017   삼성  0.303  135  412   58  125   9
# 140         230         이종환  2017   한화  0.000    1    2    0    0   0
# 145          18         고종욱  2017   넥센  0.312  123  426   70  133  24
# 149          19         구자욱  2017   삼성  0.310  144  564  108  175  39
# 154          20         국해성  2017   두산  0.209   57   86   15   18   3
# 193          22         권정웅  2017   삼성  0.212   61   99   11   21   3
# ...

# %%
df_1617 = pd.merge(df_16, df_17, on = 'batter_id', how = 'inner') 
# df_16.to_csv('out16.csv')
# df_17.to_csv('out17.csv')
df_1617
# Out:
#      batter_id batter_name_x  year_x team_x  avg_x  G_x  AB_x  R_x  H_x  2B_x  \
# 0            1           강경학    2016     한화  0.158   46   101   16   16     3
# 1            2           강구성    2016     NC  0.000    2     3    0    0     0
# 2            4           강민호    2016     롯데  0.323  116   381   65  123    26
# 3            9           강승호    2016     LG  0.184   18    38    4    7     3
# 4           12           강한울    2016    KIA  0.272  104   298   36   81    13
# 5          230           이종환    2016     한화  0.276   31    29    3    8     1
# 6           18           고종욱    2016     넥센  0.334  133   527   92  176    22
# 7           19           구자욱    2016     삼성  0.343  108   428  105  147    19
# 8           20           국해성    2016     두산  0.278   58   151   28   42    11
# 9           22           권정웅    2016     삼성  1.000    3     1    1    1     0
# 10          23           권희동    2016     NC  0.268   14    41    4   11     0
# ...

# %%
df_16_1 = df_1617[df_1617['year_x'] == 2016]

# %%
df_16_1
# Out:
#      batter_id batter_name_x  year_x team_x  avg_x  G_x  AB_x  R_x  H_x  2B_x  \
# 0            1           강경학    2016     한화  0.158   46   101   16   16     3
# 1            2           강구성    2016     NC  0.000    2     3    0    0     0
# 2            4           강민호    2016     롯데  0.323  116   381   65  123    26
# 3            9           강승호    2016     LG  0.184   18    38    4    7     3
# 4           12           강한울    2016    KIA  0.272  104   298   36   81    13
# 5          230           이종환    2016     한화  0.276   31    29    3    8     1
# 6           18           고종욱    2016     넥센  0.334  133   527   92  176    22
# 7           19           구자욱    2016     삼성  0.343  108   428  105  147    19
# 8           20           국해성    2016     두산  0.278   58   151   28   42    11
# 9           22           권정웅    2016     삼성  1.000    3     1    1    1     0
# 10          23           권희동    2016     NC  0.268   14    41    4   11     0
# ...

# %%
df_17_1 = df_1617[df_1617['year_y'] == 2017]

# %%
df_17_1
# Out:
#      batter_id batter_name_x  year_x team_x  avg_x  G_x  AB_x  R_x  H_x  2B_x  \
# 0            1           강경학    2016     한화  0.158   46   101   16   16     3
# 1            2           강구성    2016     NC  0.000    2     3    0    0     0
# 2            4           강민호    2016     롯데  0.323  116   381   65  123    26
# 3            9           강승호    2016     LG  0.184   18    38    4    7     3
# 4           12           강한울    2016    KIA  0.272  104   298   36   81    13
# 5          230           이종환    2016     한화  0.276   31    29    3    8     1
# 6           18           고종욱    2016     넥센  0.334  133   527   92  176    22
# 7           19           구자욱    2016     삼성  0.343  108   428  105  147    19
# 8           20           국해성    2016     두산  0.278   58   151   28   42    11
# 9           22           권정웅    2016     삼성  1.000    3     1    1    1     0
# 10          23           권희동    2016     NC  0.268   14    41    4   11     0
# ...

# %%
dtrain = xgb.DMatrix('out16.csv?format=csv&label_column=0')
dtest = xgb.DMatrix('out17.csv?format=csv&label_column=0')
# Out:
# [20:36:31] 214x29 matrix with 6205 entries loaded from out16.csv?format=csv&label_column=0
# [20:36:32] 218x29 matrix with 6321 entries loaded from out17.csv?format=csv&label_column=0

# %%
dtrain = xgb.DMatrix(data, label=label, missing=-999.0)

# %%
w = np.random.rand(5, 1)
dtrain = xgb.DMatrix(data, label=label, missing=-999.0, weight=w)

# %%
param = {'max_depth': 2, 'eta': 1, 'silent': 1, 'objective': 'binary:logistic'}
param['nthread'] = 4
param['eval_metric'] = 'auc'

# %%
param['eval_metric'] = ['auc', 'ams@0']

# %%
evallist = [(dtest, 'eval'), (dtrain, 'train')]

# %%
num_round = 10
bst = xgb.train(param, dtrain, num_round, evallist)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-186-668dd083f994> in <module>
#       1 num_round = 10
# ----> 2 bst = xgb.train(param, dtrain, num_round, evallist)
#
# ~\Anaconda3\lib\site-packages\xgboost\training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     214                            evals=evals,
#     215                            obj=obj, feval=feval,
# --> 216                            xgb_model=xgb_model, callbacks=callbacks)
#     217
#     218
#
# ~\Anaconda3\lib\site-packages\xgboost\training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      30             params += [('eval_metric', eval_metric)]
#      31
# ...
