# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

from matplotlib import rc, font_manager
rc('font',family="NanumSquareR")
import os

# %%
os.chdir("C:\\Users\\chanqun\\Downloads\ops")

# %%
regular=pd.read_csv("Regular_Season_Batter.csv")

# %%
regular.iloc[4]
# Out:
# batter_id                          1
# batter_name                      강경학
# year                            2016
# team                              한화
# avg                            0.158
# G                                 46
# AB                               101
# R                                 16
# H                                 16
# 2B                                 3
# 3B                                 2
# HR                                 1
# TB                                26
# RBI                                7
# SB                                 0
# CS                                 0
# BB                                 8
# HBP                                2
# SO                                30
# GDP                                5
# SLG                            0.257
# OBP                            0.232
# E                                  7
# height/weight             180cm/72kg
# year_born              1992년 08월 11일
# position                   내야수(우투좌타)
# career             광주대성초-광주동성중-광주동성고
# starting_salary              10000만원
# OPS                            0.489
# Name: 4, dtype: object

# %%
lag_1_OPS=[]
for i in range(len(regular)):
    if len(regular.loc[(regular['batter_name']==regular['batter_name'].iloc[i])&(regular['year']==regular['year'].iloc[i]-1)]['OPS']) == 0 :
        lag_1_OPS.append(np.nan)
    else:
        lag_1_OPS.append(regular.loc[(regular['batter_name']==regular['batter_name'].iloc[i])&(regular['year']==regular['year'].iloc[i]-1)]['OPS'].iloc[0])

# %%
regular['lag_1_OPS']=lag_1_OPS

# %%
regular
# Out:
#       batter_id batter_name  year  team    avg    G   AB   R    H  2B  \
# 0             0        가르시아  2018    LG  0.339   50  183  27   62   9
# 1             1         강경학  2011    한화  0.000    2    1   0    0   0
# 2             1         강경학  2014    한화  0.221   41   86  11   19   2
# 3             1         강경학  2015    한화  0.257  120  311  50   80   7
# 4             1         강경학  2016    한화  0.158   46  101  16   16   3
# 5             1         강경학  2017    한화  0.214   59   84  17   18   2
# 6             1         강경학  2018    한화  0.278   77  245  42   68  11
# 7             2         강구성  2013    NC  0.000    2    2   0    0   0
# 8             2         강구성  2015    NC  0.200    4    5   0    1   1
# 9             2         강구성  2016    NC  0.000    2    3   0    0   0
# 10            2         강구성  2017    NC  0.000    1    1   0    0   0
# 11            2         강구성  2018    NC  0.200    4    5   0    1   1
# 12          138         백승룡  2005    한화  0.127   39   63   9    8   2
# 13          138         백승룡  2006    한화  0.139   37   36   6    5   2
# 14          138         백승룡  2007    한화  0.000    8    4   3    0   0
# 15          138         백승룡  2008    한화  0.000    2    1   0    0   0
# 16          138         백승룡  2011    한화  0.176   38   51   7    9   2
# 17          138         백승룡  2012    한화  0.231   33   52   3   12   1
# 18          138         백승룡  2013    한화    NaN    2    0   0    0   0
# 19          297         진갑용  1997    OB  0.242   95  281  21   68   7
# 20          297         진갑용  1998    OB  0.269   88  253  12   68  14
# 21          297         진갑용  1999    삼성  0.212   68  156  13   33   3
# 22          297         진갑용  2000    삼성  0.273  114  297  30   81  14
# 23          297         진갑용  2001    삼성  0.306   89  314  54   96  25
# 24          297         진갑용  2002    삼성  0.281  133  462  58  130  29
# 25          297         진갑용  2003    삼성  0.290  126  435  64  126  20
# 2452  내야수(우투양타)                             석천초-대헌중-공주고           4000만원
# 2453  내야수(우투양타)                             석천초-대헌중-공주고           4000만원
#
#            OPS  lag_1_OPS
# 0     0.902000        NaN
# 1     0.000000        NaN
# 2     0.686000        NaN
# 3     0.673000   0.686000
# 4     0.489000   0.673000
# 5     0.552000   0.489000
# 6     0.774000   0.552000
# 7     0.000000        NaN
# 8     0.600000        NaN
# 9     0.000000   0.600000
# 10    0.000000   0.000000
# 11    0.600000   0.000000
# 12    0.415487        NaN
# 13    0.520531   0.415487
# 14    0.000000   0.520531
# 15    0.000000   0.000000
# 16    0.515686        NaN
# 17    0.594262   0.515686
# 18         NaN   0.594262
# 19    0.615797        NaN
# 20    0.662847   0.615797
# 21    0.575549   0.662847
# 22    0.738097   0.575549
# 23    0.831247   0.738097
# 24    0.815662   0.831247
# 25    0.847244   0.815662
# 26    0.833863   0.847244
# 27    0.757335   0.833863
# 28    0.748931   0.757335
# 29    0.667332   0.748931
# ...        ...        ...
# 2424  0.000000        NaN
# 2425  0.530488   0.000000
# 2426  0.600000        NaN
# 2427  0.522222   0.600000
# 2428  0.250000   0.522222
# 2429  0.500870        NaN
# 2430  0.167000        NaN
# 2431  0.166000   0.167000
# 2432  0.502000   0.166000
# 2433  0.375000   0.502000
# 2434  0.698000        NaN
# 2435  0.567000   0.698000
# 2436  0.802000   0.567000
# 2437  0.653000   0.802000
# 2438  0.805000   0.653000
# 2439  0.681000   0.805000
# 2440  0.739000   0.681000
# 2441  0.863000   0.739000
# 2442  0.871000   0.863000
# 2443  0.964000   0.871000
# 2444  0.884000        NaN
# 2445  0.511012        NaN
# 2446  0.759064   0.511012
# 2447  0.325000        NaN
# 2448       NaN   0.325000
# 2449  0.000000        NaN
# 2450  0.000000   0.000000
# 2451  0.000000   0.000000
# 2452  0.761000   0.000000
# 2453  0.564000   0.761000
#
# [2454 rows x 30 columns]

# %%
regular.columns
# Out:
# Index(['batter_id', 'batter_name', 'year', 'team', 'avg', 'G', 'AB', 'R', 'H',
#        '2B', '3B', 'HR', 'TB', 'RBI', 'SB', 'CS', 'BB', 'HBP', 'SO', 'GDP',
#        'SLG', 'OBP', 'E', 'height/weight', 'year_born', 'position', 'career',
#        'starting_salary', 'OPS', 'lag_1_OPS'],
#       dtype='object')

# %%
for j in [ 'avg', 'G', 'AB', 'R', 'H','2B', '3B', 'HR', 'TB', 'RBI', 'SB', 'CS', 'BB', 'HBP', 'SO', 'GDP','SLG', 'OBP', 'E']:
    lag_1_avg=[]
    for i in range(len(regular)):
        if len(regular.loc[(regular['batter_name']==regular['batter_name'].iloc[i])&(regular['year']==regular['year'].iloc[i]-1)][j]) == 0 :
            lag_1_avg.append(np.nan)
        else:
            lag_1_avg.append(regular.loc[(regular['batter_name']==regular['batter_name'].iloc[i])&(regular['year']==regular['year'].iloc[i]-1)][j].iloc[0])
    regular['lag_1_'+j]=lag_1_avg
    print(j)
# Out:
# avg
# G
# AB
# R
# H
# 2B
# 3B
# HR
# TB
# RBI
# SB
# CS
# BB
# HBP
# SO
# GDP
# SLG
# OBP
# E

# %%
regular.columns
# Out:
# Index(['batter_id', 'batter_name', 'year', 'team', 'avg', 'G', 'AB', 'R', 'H',
#        '2B', '3B', 'HR', 'TB', 'RBI', 'SB', 'CS', 'BB', 'HBP', 'SO', 'GDP',
#        'SLG', 'OBP', 'E', 'height/weight', 'year_born', 'position', 'career',
#        'starting_salary', 'OPS', 'lag_1_OPS', 'lag_1_avg', 'lag_1_G',
#        'lag_1_AB', 'lag_1_R', 'lag_1_H', 'lag_1_2B', 'lag_1_3B', 'lag_1_HR',
#        'lag_1_TB', 'lag_1_RBI', 'lag_1_SB', 'lag_1_CS', 'lag_1_BB',
#        'lag_1_HBP', 'lag_1_SO', 'lag_1_GDP', 'lag_1_SLG', 'lag_1_OBP',
#        'lag_1_E'],
#       dtype='object')

# %%
regular=regular.loc[-regular["OPS"].isnull(),]

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
y=regular['OPS']
X=regular[['lag_1_OPS', 'lag_1_avg', 'lag_1_G',
       'lag_1_AB', 'lag_1_R', 'lag_1_H', 'lag_1_2B', 'lag_1_3B', 'lag_1_HR',
       'lag_1_TB', 'lag_1_RBI', 'lag_1_SB', 'lag_1_CS', 'lag_1_BB',
       'lag_1_HBP', 'lag_1_SO', 'lag_1_GDP', 'lag_1_SLG', 'lag_1_OBP',
       'lag_1_E']]

# %%
rf=RandomForestRegressor(n_estimators=500)

# %%
rf.fit(X.fillna(-1),y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
train=regular.loc[regular['year']<=2017,]
test=regular.loc[regular['year']<=2018,]
y_train=train['OPS']
X_train=train[['lag_1_OPS', 'lag_1_avg', 'lag_1_G',
       'lag_1_AB', 'lag_1_R', 'lag_1_H', 'lag_1_2B', 'lag_1_3B', 'lag_1_HR',
       'lag_1_TB', 'lag_1_RBI', 'lag_1_SB', 'lag_1_CS', 'lag_1_BB',
       'lag_1_HBP', 'lag_1_SO', 'lag_1_GDP', 'lag_1_SLG', 'lag_1_OBP',
       'lag_1_E']]
y_test=test['OPS']
X_test=test[['lag_1_OPS', 'lag_1_avg', 'lag_1_G',
       'lag_1_AB', 'lag_1_R', 'lag_1_H', 'lag_1_2B', 'lag_1_3B', 'lag_1_HR',
       'lag_1_TB', 'lag_1_RBI', 'lag_1_SB', 'lag_1_CS', 'lag_1_BB',
       'lag_1_HBP', 'lag_1_SO', 'lag_1_GDP', 'lag_1_SLG', 'lag_1_OBP',
       'lag_1_E']]

# %%
rf=RandomForestRegressor(n_estimators=500)
rf.fit(X_train.fillna(-1),y_train,sample_weight=train['AB'])
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(real,pred,sample_weight=ab)**0.5
# Out:
# 0.10301815562356802

# %%
pred=rf.predict(X_test.fillna(-1))

# %%
real=test['OPS']
ab=test['AB']

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(real,pred,sample_weight=ab)**0.5
# Out:
# 0.10301815562356802
